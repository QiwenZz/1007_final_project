# %%
import pandas as pd

# %%
df = pd.read_csv('data/train.csv')

# %%
df.isnull().sum()
# Out:
# timestamp         0
# Asset_ID          0
# Count             0
# Open              0
# High              0
# Low               0
# Close             0
# Volume            0
# VWAP              9
# Target       750338
# dtype: int64

# %%
df[df['Asset_ID']==0]
# Out:
#            timestamp  Asset_ID  Count      Open      High       Low     Close  \
# 1         1514764860         0    5.0    8.5300    8.5300    8.5300    8.5300
# 9         1514764920         0    7.0    8.5300    8.5300    8.5145    8.5145
# 17        1514764980         0   45.0    8.5065    8.5299    8.4848    8.4848
# 25        1514765040         0   14.0    8.5009    8.5066    8.4744    8.5009
# 33        1514765100         0    5.0    8.5007    8.5007    8.4560    8.4560
# ...              ...       ...    ...       ...       ...       ...       ...
# 24236738  1632182160         0  277.0  364.1115  364.2000  362.7000  362.9180
# 24236752  1632182220         0  296.0  362.9265  363.2000  362.1000  362.2000
# 24236766  1632182280         0  319.0  362.2310  362.4000  361.7000  361.8580
# 24236780  1632182340         0  588.0  362.0120  364.3000  361.8000  364.1145
# 24236794  1632182400         0  429.0  364.1150  364.5000  363.7000  363.7575
#
# ...
